# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
alerts = pd.read_csv('D:/Sinau/danthon-dsw2021/co/data_pre/alerts_pre.csv')
data_train = pd.read_csv('D:/Sinau/danthon-dsw2021/co/data_pre/data_train_pre.csv')

# %%
data_train.head(3)
#Unique Ids which combines S2 Token Lvl 15, Dates, and Hours
# Out:
#                        Ids  Labels      token        date  hour
# 0  2e69e9384_2020-10-06_13    True  2e69e9384  2020-10-06    13
# 1  2e6992c7c_2020-10-02_17    True  2e6992c7c  2020-10-02    17
# 2  2e69ef474_2020-09-13_19    True  2e69ef474  2020-09-13    19

# %%
alerts.head(3)
# Out:
#           id     pub_millis s2token_15  road_type               street  \
# 0  179156987  1604487892000  2e69eb7f4          6  N8 Jalan Raya Bogor
# 1  173055165  1601895721000  2e699ad9c          2   Flyover Tegal Gede
# 2  173802602  1602464394000  2e69eec0c          2      Tanjakan Kembar
#
#        city  magvar  reliability  report_rating  confidence           type
# 0     Depok     170            7              1           1            JAM
# 1  Cikarang     319           10              5           0  WEATHERHAZARD
# 2     Depok     310            5              3           0            JAM

# %%
# df_join = alerts.merge(data_train, left_on='s2token_15', right_on='token')
# pd.merge(data_train, alerts, on=['token','s2token_15'], )

# %%
df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [1, 2, 3, 5]})
df2 = pd.DataFrame({'rkey': ['foo', 'baz', 'foo'],
                    'value': [5, 6, 7]})

# %%
df1
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5

# %%
df2
# Out:
#   rkey  value
# 0  foo      5
# 1  baz      6
# 2  foo      7

# %%
pd.concat([df1, df2], axis=0)
# Out:
#   lkey  value rkey
# 0  foo      1  NaN
# 1  bar      2  NaN
# 2  baz      3  NaN
# 3  foo      5  NaN
# 0  NaN      5  foo
# 1  NaN      6  baz
# 2  NaN      7  foo

# %%
df1.merge(df2, how='inner') #left_on='lkey', right_on='rkey',
# Out:
#   lkey  value rkey
# 0  foo      5  foo

# %%
df_join
# Out:
#                   id     pub_millis s2token_15  road_type  \
# 0          179156987  1604487892000  2e69eb7f4          6
# 1          179156987  1604487892000  2e69eb7f4          6
# 2          179156987  1604487892000  2e69eb7f4          6
# 3          179156987  1604487892000  2e69eb7f4          6
# 4          179156987  1604487892000  2e69eb7f4          6
# ...              ...            ...        ...        ...
# 553578506  167325353  1599357437000  2e69eef9c          1
# 553578507  167325426  1599357437000  2e69eef9c          1
# 553578508  167325207  1599357437000  2e69eef9c          1
# 553578509  167325570  1599357437000  2e69eef9c          1
# 553578510  167325497  1599357437000  2e69eef9c          1
#
#                         street   city  magvar  reliability  report_rating  \
# 0          N8 Jalan Raya Bogor  Depok     170            7              1
# 1          N8 Jalan Raya Bogor  Depok     170            7              1
# ...

# %%
df_join.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-36-a96d649cef4a> in <module>
# ----> 1 df_join.duplicated().sum()
#
# d:\Sinau\Data Science Weekend\env\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    5406
#    5407         vals = (col.values for name, col in self.items() if name in subset)
# -> 5408         labels, shape = map(list, zip(*map(f, vals)))
#    5409
#    5410         ids = get_group_index(labels, shape, sort=False, xnull=False)
#
# d:\Sinau\Data Science Weekend\env\lib\site-packages\pandas\core\frame.py in f(vals)
#    5380
#    5381         def f(vals):
# -> 5382             labels, shape = algorithms.factorize(
#    5383                 vals, size_hint=min(len(self), SIZE_HINT_LIMIT)
#    5384             )
#
# ...

# %%
df_join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 553578511 entries, 0 to 553578510
# Data columns (total 16 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   id             int64
#  1   pub_millis     int64
#  2   s2token_15     object
#  3   road_type      int64
#  4   street         object
#  5   city           object
#  6   magvar         int64
#  7   reliability    int64
#  8   report_rating  int64
#  9   confidence     int64
#  10  type           object
#  11  Ids            object
#  12  Labels         bool
#  13  token          object
#  14  date           object
#  15  hour           int64
# dtypes: bool(1), int64(8), object(7)
# memory usage: 82.6+ GB

# %%
df_join[:10]
# Out:
#           id     pub_millis s2token_15  road_type               street   city  \
# 0  179156987  1604487892000  2e69eb7f4          6  N8 Jalan Raya Bogor  Depok
# 1  179156987  1604487892000  2e69eb7f4          6  N8 Jalan Raya Bogor  Depok
# 2  179156987  1604487892000  2e69eb7f4          6  N8 Jalan Raya Bogor  Depok
# 3  179156987  1604487892000  2e69eb7f4          6  N8 Jalan Raya Bogor  Depok
# 4  179156987  1604487892000  2e69eb7f4          6  N8 Jalan Raya Bogor  Depok
# 5  179156987  1604487892000  2e69eb7f4          6  N8 Jalan Raya Bogor  Depok
# 6  179156987  1604487892000  2e69eb7f4          6  N8 Jalan Raya Bogor  Depok
# 7  179156987  1604487892000  2e69eb7f4          6  N8 Jalan Raya Bogor  Depok
# 8  179156987  1604487892000  2e69eb7f4          6  N8 Jalan Raya Bogor  Depok
# 9  179156987  1604487892000  2e69eb7f4          6  N8 Jalan Raya Bogor  Depok
#
#    magvar  reliability  report_rating  confidence type  \
# ...
