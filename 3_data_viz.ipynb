# %%
import pandas as pd
import numpy as np
import seaborn as sns
import joblib
import warnings as wrn
wrn.filterwarnings('ignore', category = DeprecationWarning) 
wrn.filterwarnings('ignore', category = FutureWarning) 
wrn.filterwarnings('ignore', category = UserWarning)

# %%
num_data = joblib.load('output/num_data.pkl')
cat_data = joblib.load('output/cat_data_imputted.pkl')

# %% [markdown]
# ### Data Viz

# %%
def plot_dist(variable_name):
    sns.distplot(num_data[variable_name])

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
plot_dist('speed')

# %%
plot_dist('detection_date_millis')

# %%
plot_dist('update_date_millis')

# %%
plot_dist('regular_speed')

# %%
plot_dist('delay_seconds')

# %%
plot_dist('seconds')

# %%
plot_dist('length')

# %%
plot_dist('trend')

# %%
plot_dist('severity')

# %%
plot_dist('jam_level')

# %%
plot_dist('drivers_count')

# %%
plot_dist('alerts_count')

# %%
plot_dist('n_thumbs_up')
